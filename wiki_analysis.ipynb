# %% [markdown]
# # Functions

# %%
import unittest
import os
import bs4

def get_files_in_dir(dir_name, extension = None):
    if os.path.exists(dir_name) == False:
        return None
    if os.path.isfile(dir_name):
        return None
    files = os.listdir(dir_name)
    if extension is not None: # we have a filter 
        files = [f for f in files if f.endswith(extension)]
    return files

def get_bs4_obj(filename):
    if os.path.exists(filename):
        with open(filename) as f:
            bs4_obj = bs4.BeautifulSoup(f)
        return bs4_obj
    else:
        return None


    
def get_alum_list(filename):
    dom = get_bs4_obj(filename)
    if dom == None:
        return []
    h2s_filt = [h2 for h2 in dom.find_all("h2") if "lumni" in h2.text]
    
    if len(h2s_filt) == 0:
        return []
    
    sib = h2s_filt[0].next_sibling
    # traverse, accumulating uls
    # that are siblings of h2
    uls = []
    while sib != None:
        if sib.name == "ul":
            uls.append(sib)
        if sib.name == "h2": # end of the section
            break
        sib = sib.next_sibling
    # dig into the uls
    list_texts = []
    for ul in uls: # iterate all sibling uls
        lis = ul.find_all("li")
        for li in lis: # iterate list items
            list_text = li.text
            list_texts.append(list_text) # add text 
    return list_texts

get_alum_list('./test_html_files/uol.html')
# Out:
# ['Name 1 ', 'Name 2 ', 'Name 3 ', 'Name 4 ']

# %% [markdown]
# # Unit tests

# %%
class TestListFiles(unittest.TestCase):
    def test_list_xists(self):
        self.assertIsNotNone(get_files_in_dir)
    
    def test_returns_list(self):
        res = get_files_in_dir("/")
        self.assertEqual(  type(res), list)
    
    def test_nonexistent(self):
        res = get_files_in_dir("/i/do/not/exist")
        self.assertIsNone(res)
    
    def test_nofilenames(self):
        res = get_files_in_dir("./test_files/test1.txt")
        self.assertIsNone(res)
        
    def test_get_two(self):
        res = get_files_in_dir("./test_files/")
        self.assertEqual(len(res), 3)
    
    def test_filter_to_two(self):
        res = get_files_in_dir("./test_files/", "txt")
        self.assertEqual(len(res), 2)
    
    def test_filter_to_one(self):
        res = get_files_in_dir("./test_files/", "html")
        self.assertEqual(len(res), 1)
    
    def test_filter_to_one_ext(self):
        res = get_files_in_dir("./test_files/", "html")
        
        self.assertTrue(res[0].endswith("html"))
    
    

    

unittest.main(argv=['ingored', '-v'], exit=False)
# Out:
# test_alum_func_exists (__main__.TestExtractAlumni) ... ok
# test_alum_func_ret_list (__main__.TestExtractAlumni) ... ok
# test_filter_to_one (__main__.TestListFiles) ... ok
# test_filter_to_one_ext (__main__.TestListFiles) ... ok
# test_filter_to_two (__main__.TestListFiles) ... ok
# test_get_two (__main__.TestListFiles) ... ok
# test_list_xists (__main__.TestListFiles) ... ok
# test_nofilenames (__main__.TestListFiles) ... ok
# test_nonexistent (__main__.TestListFiles) ... ok
# test_returns_list (__main__.TestListFiles) ... ok
#
# ----------------------------------------------------------------------
# Ran 10 tests in 0.007s
#
# OK

# %%
class TestHTMLParse(unittest.TestCase):
    def test_get_alums_exists(self):
        self.assertIsNotNone(get_alum_list)
    
    def test_returns_list(self):
        res = get_alum_list("something.html")
        self.assertEqual( type(res), list )
    
    def test_load_html_not_none(self):
        res = get_bs4_obj("./test_html_files/uol.html")
        self.assertEqual(type(res), bs4.BeautifulSoup)
    
    def test_ret_4(self):
        res = get_alum_list('./test_html_files/uol.html')
        self.assertEqual(len(res), 4)
    
    def test_uni_london_works(self):
        res = get_alum_list('./test_html_files/uol_real.html')
        self.assertGreater(len(res), 0)
    
    def test_uni_leeds(self):
        res = get_alum_list('./test_html_files/leeds.html')
        self.assertIsNotNone(res)
    
    
        
        
unittest.main(argv=['ingored', '-v'], exit=False)
# Out:
# test_get_alums_exists (__main__.TestHTMLParse) ... ok
# test_load_html_not_none (__main__.TestHTMLParse) ... ok
# test_ret_4 (__main__.TestHTMLParse) ... ok
# test_returns_list (__main__.TestHTMLParse) ... ok
# test_uni_leeds (__main__.TestHTMLParse) ... ok
# test_uni_london_works (__main__.TestHTMLParse) ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.335s
#
# OK

# %% [markdown]
# # Data analysis

# %%
dirname = "../../Data/wikipedia-university-pages/"
files = get_files_in_dir(dirname)
print("Found ", len(files))

for f in files:
    alums = get_alum_list(dirname + f)
    if len(alums) > 0:
        print("Found ", len(alums), "in",  f)
# Out:
# Found  1065
# Found  9 in Wye_College.html
# Found  21 in Queen's_College,_Taunton.html
# Found  5 in St_Dominic's_Sixth_Form_College.html
# Found  3 in University_of_Brighton.html
# Found  44 in University_of_Ibadan.html
# Found  12 in Woodhouse_College.html
# Found  2 in Barnet_and_Southgate_College.html
# Found  55 in List_of_University_College_London_people_in_the_Law.html
# Found  11 in University_of_Worcester.html
# Found  24 in Harrow_College.html
# Found  47 in UCL_Medical_School.html
# Found  2 in St._Matthew's_University.html
# Found  10 in University_of_Bedfordshire.html
# Found  39 in Ealing,_Hammersmith_and_West_London_College.html
# Found  6 in London_Consortium.html
# Found  1 in Institute_of_Commonwealth_Studies.html
# Found  4 in Havering_Sixth_Form_College.html
# Found  9 in College_of_North_West_London.html
# Found  11 in University_of_Aberdeen.html
# Found  10 in Royal_College_of_Music.html
# Found  88 in University_of_the_Arts_London.html
# Found  2 in Barts_and_The_London_School_of_Medicine_and_Dentistry.html
# Found  6 in University_of_Derby.html
# Found  10 in Liverpool_School_of_Tropical_Medicine.html
# Found  15 in York_St_John_University.html
# Found  13 in Croydon_College.html
# Found  39 in University_of_the_West_Indies.html
# Found  9 in Southampton_Solent_University.html
# Found  62 in Brunel_University.html
# Found  24 in University_of_Glasgow.html
# Found  111 in RADA.html
# Found  1 in Greenwich_Community_College.html
# Found  19 in Regent's_University_London.html
# Found  11 in Imperial_College_London.html
# Found  14 in Queen's_College,_Birmingham.html
# Found  11 in Kingston_College_(England).html
# Found  99 in University_of_London_International_Programmes.html
# Found  26 in Open_University.html
# Found  10 in University_of_East_Anglia.html
# Found  8 in Queen_Elizabeth_College.html
# Found  21 in John_Ruskin_College.html
# Found  2 in University_of_the_Highlands_and_Islands.html
# Found  9 in Canterbury_Christ_Church_University.html
# Found  47 in Liverpool_John_Moores_University.html
# Found  6 in West_Thames_College.html
# Found  1 in Capel_Manor_College.html
# Found  33 in Regent's_Park_College.html
# Found  1 in Newham_Sixth_Form_College.html
# Found  18 in Richmond_upon_Thames_College.html
# Found  76 in University_of_Dundee.html
# Found  5 in University_of_Cumbria.html
# Found  47 in University_of_Greenwich.html
# Found  4 in Bromley_College_of_Further_&_Higher_Education.html
# Found  34 in Sheffield_Hallam_University.html
# Found  22 in University_of_Sunderland.html
# Found  112 in University_of_Liverpool.html
# Found  1 in University_of_St_Mark_&_St_John.html
# Found  530 in List_of_people_associated_with_University_College_London.html
# Found  4 in Ceylon_Technical_College.html
# Found  2 in University_College_Lahore.html
# Found  10 in London_School_of_Journalism.html
# Found  4 in Carshalton_College.html
# Found  17 in Glasgow_Caledonian_University.html
# Found  9 in City_and_Islington_College.html
# Found  1 in City_of_Westminster_College.html
# Found  14 in Buckinghamshire_New_University.html
# Found  24 in Huddersfield_College.html
# Found  33 in University_of_Nairobi.html
# Found  40 in Mason_Science_College.html
# Found  38 in University_of_Hertfordshire.html
# Found  56 in De_Montfort_University.html
# Found  19 in Arts_University_Bournemouth.html
# Found  93 in University_of_Reading.html
# Found  51 in King's_College_School_of_Medicine_and_Dentistry.html
# Found  45 in Heriot-Watt_University.html
# Found  5 in University_of_Cambridge.html
# Found  10 in University_of_Surrey.html
# Found  62 in Brunel_University_London.html
# Found  65 in University_of_Bath.html
# Found  118 in Cardiff_University.html
# Found  37 in Kensington_and_Chelsea_College.html
# Found  11 in University_of_Wales_Trinity_Saint_David.html
# Found  25 in Leyton_Sixth_Form_College.html
# Found  12 in UCL_Faculty_of_Life_Sciences.html
# Found  11 in University_of_Stirling.html
# Found  38 in Northumbria_University.html
# Found  9 in Slade_School_of_Fine_Art.html
# Found  26 in Anglia_Ruskin_University.html
# Found  28 in University_of_the_West_of_England.html
# Found  12 in Harper_Adams_University.html
# Found  21 in UCL_Faculty_of_Laws.html
# Found  3 in Royal_Veterinary_College.html
# Found  13 in Abertay_University.html
# Found  53 in University_of_South_Wales.html
# Found  8 in University_of_Edinburgh.html
# Found  11 in Imperial_College.html
# Found  46 in School_of_Slavonic_and_East_European_Studies.html
# Found  14 in Peking_University.html
# Found  15 in Liverpool_Hope_University.html
# Found  9 in Barking_and_Dagenham_College.html
# Found  46 in UCL_School_of_Slavonic_and_East_European_Studies.html
# Found  9 in Richmond,_The_American_International_University_in_London.html
# Found  33 in Regent's_Park_College,_Oxford.html
# Found  6 in Bexley_College.html
# Found  91 in Swansea_University.html
# Found  9 in Lewisham_Southwark_College.html
